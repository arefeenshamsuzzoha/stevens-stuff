# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
project_data = pd.read_csv('data.csv')

# %%
project_data.head()
# Out:
#    Close_ETF       oil      gold       JPM
# 0  97.349998  0.039242  0.004668  0.032258
# 1  97.750000  0.001953 -0.001366 -0.002948
# 2  99.160004 -0.031514 -0.007937  0.025724
# 3  99.650002  0.034552  0.014621  0.011819
# 4  99.260002  0.013619 -0.011419  0.000855

# %%
pop_means = project_data.mean()
print(pop_means)
# Out:
# Close_ETF    121.152960
# oil            0.001030
# gold           0.000663
# JPM            0.000530
# dtype: float64

# %%
pop_stdev = project_data.std()
print(pop_stdev)
# Out:
# Close_ETF    12.569790
# oil           0.021093
# gold          0.011289
# JPM           0.011017
# dtype: float64

# %%
project_data.corr(method='pearson')
# Out:
#            Close_ETF       oil      gold       JPM
# Close_ETF   1.000000 -0.009045  0.022996  0.036807
# oil        -0.009045  1.000000  0.235650 -0.120849
# gold        0.022996  0.235650  1.000000  0.100170
# JPM         0.036807 -0.120849  0.100170  1.000000

# %% [markdown]
# ### second part of the project
# ### histogram

# %%
project_data.hist(column = "Close_ETF")
project_data.hist(column = "oil")
project_data.hist(column = "gold")
project_data.hist(column = "JPM")
# Out:
# array([[<AxesSubplot:title={'center':'JPM'}>]], dtype=object)

# %%
from pandas import read_csv
import matplotlib.pyplot as plt 

timeseries = read_csv('data.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(type(timeseries))
print(timeseries.head(10))
print(timeseries.size)
print(timeseries.describe())

plt.plot(timeseries)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                  oil      gold       JPM
# Close_ETF
# 97.349998   0.039242  0.004668  0.032258
# 97.750000   0.001953 -0.001366 -0.002948
# 99.160004  -0.031514 -0.007937  0.025724
# 99.650002   0.034552  0.014621  0.011819
# 99.260002   0.013619 -0.011419  0.000855
# 98.250000   0.003199 -0.005501 -0.038998
# 99.250000   0.011480 -0.027600  0.009479
# 100.300003  0.014187  0.008191  0.013498
# 100.610001 -0.023624 -0.004513  0.004632
# 99.559998  -0.024833  0.010201  0.000000
# 3000
#                oil         gold          JPM
# count  1000.000000  1000.000000  1000.000000
# mean      0.001030     0.000663     0.000530
# std       0.021093     0.011289     0.011017
# min      -0.116533    -0.065805    -0.048217
# 25%      -0.012461    -0.004816    -0.005538
# 50%       0.001243     0.001030     0.000386
# 75%       0.014278     0.007482     0.006966
# max       0.087726     0.042199     0.057480
